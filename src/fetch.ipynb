# %%
from google.transit import gtfs_realtime_pb2
import urllib3
id =    "50828"
url = "https://proxy.transport.data.gouv.fr"
url = "https://transport.data.gouv.fr/api/datasets/"+id

http = urllib3.PoolManager()
response = http.request('GET',url)
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# c:\Users\Xxsaf\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# c:\Users\Xxsaf\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# ...

# %%
feed = gtfs_realtime_pb2.FeedMessage()
feed.ParseFromString(response.read())
for entity in feed.entity:
    if entity.HasField('trip_update'):
            print (entity.trip_update)

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(response.data, 'html.parser')

print(soup)
# Out:
# <!DOCTYPE html>
# <html data-fr-scheme="light" data-fr-theme="light" lang="fr">
# <head>
# <meta charset="utf-8"/>
# <title>GTFS DiviaMobilités - data.gouv.fr</title>
# <meta content="website" property="og:type"/>
# <meta content="GTFS DiviaMobilités - data.gouv.fr" property="og:title"/>
# <link href="http://www.etalab.gouv.fr/" rel="author"/>
# <meta content="Offre théorique du réseau DiviaMobilités au format GTFS…" name="description"/>
# <meta content="Offre théorique du réseau DiviaMobilités au format GTFS…" property="og:description"/>
# <meta content="https://static.data.gouv.fr/avatars/ef/7f0db273714507bd61bdb1f44b53cd-100.jpg" property="og:image"/>
# <meta content="opendata, udata, jeu de données, deplacements, transports" name="keywords"/>
# <meta content="https://static.data.gouv.fr/_themes/gouvfr/" name="theme-static-root"/>
# <meta content="https://static.data.gouv.fr/static/" name="static-root"/>
# <meta content="/api/1/" name="api-root"/>
# ...

# %%
import requests
headers = {
    "user-agent": "Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36"
}
rep = requests.get(url, headers=headers)
rep.encoding = 'utf-8'
html = rep.text

# %%
url = "https://transport.data.gouv.fr/api/datasets/5d31d8b69ce2e703da90b699"
print(html)
# nsoup = BeautifulSoup(html, 'html.parser')
# print(nsoup)
# Out:
# {"aom":{"name":"Dijon Métropole","siren":"242100410"},"community_resources":[],"covered_area":{"aom":{"name":"Dijon Métropole","siren":"242100410"},"name":"Dijon Métropole","type":"aom"},"created_at":"2019-07-19","datagouv_id":"5d31d8b69ce2e703da90b699","history":[{"resource_id":10354,"payload":{"dataset_id":232,"download_datetime":"2022-09-27T18:04:16.634444Z","filename":"10354/10354.20220927.180416.634444.zip","filenames":["agency.txt","calendar.txt","calendar_dates.txt","routes.txt","shapes.txt","stop_times.txt","stops.txt","trips.txt"],"filesize":2842317,"format":"GTFS","http_headers":{"content-disposition":"attachment; filename=\"GTFS_DiviaMobilites_current.zip\"","content-length":"2843131","content-type":"application/zip","expires":"Fri, 01 Jan 1990 00:00:00 GMT"},"latest_schema_version_to_date":null,"permanent_url":"https://transport-data-gouv-fr-resource-history-prod.cellar-c2.services.clever-cloud.com/10354/10354.20220927.180416.634444.zip","resource_metadata":{"end_date":"2
# ...

# %%
import requests

url = "https://proxy.transport.data.gouv.fr/resource/divia-dijon-gtfs-rt-trip-update"
url = "https://data.explore.divia.fr/api/datasets/1.0/gtfs-divia-mobilites/attachments/gtfs_diviamobilites_current_zip"
headers = {
    "user-agent": "Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36"
}
rep = requests.get(url, headers=headers)
# rep.encoding = 'utf-8'
# html = rep.text

# %%
print(rep.text)

# file = open('file.gtfs', 'w')
# file.write(html)
# file.close()
# Out:
# 2.0���
# 2-L3-1-1-153300
#
# 2-L3-1-1-153300 *3-L30&����������������"3-484(��������"3-547(��������"3-486(��������"3-487(��������"3-488(��������"3-489(��������"3-490(������"3-491(������"3-1601(��������"3-1602(��������"3-865(��������"3-1212(ȸ��ȸ��"3-17(������"3-18(ƹ��ƹ��"3-19(��������"3-20(ͺ��ͺ��"3-1603(��������"3-1219(��������"3-1604(��������"3-1605(������"3-1288(��������"3-1230(��������"3-1442(��������"3-396(��������"3-397(��������"3-398(��������"3-399(��������"3-394(��������"3-1339(��������"3-402(��������"3-345(��������"3-364(��������"3-356(
# 24392439 �����
# 2-L3-2-1-144900�
#
# ...

# %%
# import pygtfs
# sched = pygtfs.Schedule(":memory:")
# pygtfs.append_feed(sched, "data.zip")  


from google.transit import gtfs_realtime_pb2
import urllib

feed = gtfs_realtime_pb2.FeedMessage()

url = "https://proxy.transport.data.gouv.fr/resource/divia-dijon-gtfs-rt-trip-update"
headers = {
    "user-agent": "Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36"
}
response = requests.get(url, headers=headers)


# request = urllib.request.Request(url)
# request.add_header("user-agent", "Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36")
# response = urllib.request.urlopen(request)
feed.ParseFromString(response.content)
for entity in feed.entity:
    if entity.HasField('trip_update'):
        print( entity.trip_update)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-9ab2eb9d529b> in <module>
#      22 for entity in feed.entity:
#      23     if entity.HasField('trip_update'):
# ---> 24         print( entity.trip_update.trip_id)
#
# AttributeError: trip_id
