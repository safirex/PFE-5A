# %%
from sqlalchemy import create_engine
from sqlalchemy.types import *
uri = 'mysql://root:eudeseude@localhost:3306/pfe'
engine = create_engine(uri, echo=False)
conn = engine.connect('test_static_data')

# %%
import pygtfs
# sched = pygtfs.Schedule(":memory:")
sched = pygtfs.Schedule(uri)
filepath = 'C:/Users/Xxsaf/Downloads/10354.20220927.180416.634444.zip'
pygtfs.append_feed(sched, filepath)
# Out:
# ---------------------------------------------------------------------------
# CompileError                              Traceback (most recent call last)
# c:\Users\Xxsaf\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\sql\compiler.py in visit_create_table(self, create, **kw)
#    4346             try:
# -> 4347                 processed = self.process(
#    4348                     create_column, first_pk=column.primary_key and not first_pk
#
# c:\Users\Xxsaf\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\sql\compiler.py in process(self, obj, **kwargs)
#     485     def process(self, obj, **kwargs):
# --> 486         return obj._compiler_dispatch(self, **kwargs)
#     487
#
# c:\Users\Xxsaf\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\sql\visitors.py in _compiler_dispatch(self, visitor, **kw)
#      81         else:
# ---> 82             return meth(self, **kw)
#      83
#
# ...
